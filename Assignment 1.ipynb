# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf
import numpy as np

# 1. Create two sample tensors

tensor1 = tf.constant([[1, 2], [3, 4]])
tensor2 = tf.constant([[5, 6], [7, 8]])

# 2. Perform element-wise addition
added_tensors = tf.add(tensor1, tensor2)
print("Element-wise Addition:\n", added_tensors.numpy()) 
# element-wise addition of tensor1 and tensor2
#  [[ 6  8]
#   [10 12]]

# 3. Perform element-wise multiplication
multiplied_tensors = tf.multiply(tensor1, tensor2)
print("Element-wise Multiplication:\n", multiplied_tensors.numpy())
# element-wise multiplication of tensor1 and tensor2
#  [[ 5 12]
#   [21 32]]

# 4. Reshape a tensor
reshaped_tensor = tf.reshape(tensor1, [1, 4])
print("Reshaped Tensor:\n", reshaped_tensor.numpy())
# Tensor 1 is reshaped from 2x2 to 1x4.
#  [[1 2 3 4]]

# 5. Slicing and indexing a tensor
sliced_tensor = tensor2[:, 1]
indexed_value = tensor1[0, 1]
print("Indexed Value (tensor1[0,1]):", indexed_value.numpy())
print("Sliced Tensor (second column of tensor2):\n", sliced_tensor.numpy())

# Slicing to get the second column of tensor2 results in [6 8]
# Indexing to get the element at first row, second column of tensor1 results in 2

# 6. Compute the mean of a tensor

tensor4 = tf.constant([ 1, 4, 2, 3])
mean_tensor = tf.reduce_mean(tensor4)
print("Mean of tensor4 int:\n", mean_tensor.numpy())
# Integers are truncuated, so output is 2
tensor4 = tf.constant([ 1.0, 4.0, 2.0, 3.0])
mean_tensor = tf.reduce_mean(tensor4)
print("Mean of tensor4 float:\n", mean_tensor.numpy())
# if float is used we get 2.5

# 7. Splitting a tensor
tensor5 = tf.constant([[1, 2, 3, 4], [5, 6, 7, 8]])
split_tensors = tf.split(tensor5, num_or_size_splits=2, axis=1)
print("Split Tensors:\n", [t.numpy() for t in split_tensors])

#tensor 5 is split into two tensors along the second axis (columns).
# Split Tensors:
#[array([[1, 2],
#        [5, 6]]), 
# array([[3, 4],
#        [7, 8]])]

# 8. Basic math operations

print("tensor1",tensor1.numpy(), "tensor2",tensor2.numpy()) # tensorstensor1 [[1 2] [3 4]] tensor2 [[5 6] [7 8]]
print("addition",tf.add(tensor1, 4))  # Addition [[ 5  6] [ 7  8]]
print("subtraction",tf.subtract(tensor2, 10))  # Subtraction [[-5 -4] [-3 -2]]
print("multiplication",tf.multiply(tensor1, tensor2))  # Multiplication [[ 5 12] [21 32]]_
# Out:
# Element-wise Addition:
#  [[ 6  8]
#  [10 12]]
# Element-wise Multiplication:
#  [[ 5 12]
#  [21 32]]
# Reshaped Tensor:
#  [[1 2 3 4]]
# Indexed Value (tensor1[0,1]): 2
# Sliced Tensor (second column of tensor2):
#  [6 8]
# Mean of tensor4 int:
#  2
# Mean of tensor4 float:
#  2.5
# Split Tensors:
#  [array([[1, 2],
#        [5, 6]], dtype=int32), array([[3, 4],
#        [7, 8]], dtype=int32)]
# tensor1 [[1 2]
#  [3 4]] tensor2 [[5 6]
#  [7 8]]
# addition tf.Tensor(
# [[5 6]
#  [7 8]], shape=(2, 2), dtype=int32)
# subtraction tf.Tensor(
# [[-5 -4]
#  [-3 -2]], shape=(2, 2), dtype=int32)
# multiplication tf.Tensor(
# [[ 5 12]
#  [21 32]], shape=(2, 2), dtype=int32)

# %%
import tensorflow as tf
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10)
])
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

print("Model Summary:")
model.summary()
# Out:
# Model Summary:
# c:\Users\nisse\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten

# 1. Load and preprocess the dataset
(x_train,y_train),(x_test,y_test) = keras.datasets.mnist.load_data()

# normalizing the data
x_train, x_test = x_train / 255.0, x_test / 255.0

# 2. Define a simple neural network model for classification


model= Sequential()
model.add(Flatten(input_shape=x_train[0].shape))
model.add(Dense(128, activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.summary()

# 3. compile the model

model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# 4. Train the model
history = model.fit(x_train,y_train,epochs=20,validation_split=0.2)

# 5. Evaluate the model and plot performance indicators
# 6. Plot training and validation loss over epochs

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# 7. Plot training and validation accuracy over epochs

y_prob = model.predict(x_test)
y_pred = y_prob.argmax(axis=1)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# 8. Display test loss and accuracy

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')

# sources: https://www.tensorflow.org/datasets/keras_example
# https://medium.com/@azimkhan8018/a-beginners-guide-to-deep-learning-with-mnist-dataset-0894f7183344
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,938 (409.91 KB)
#  Trainable params: 104,938 (409.91 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9172 - loss: 0.2801 - val_accuracy: 0.9566 - val_loss: 0.1472
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9650 - loss: 0.1162 - val_accuracy: 0.9610 - val_loss: 0.1311
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9754 - loss: 0.0812 - val_accuracy: 0.9692 - val_loss: 0.1022
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9805 - loss: 0.0619 - val_accuracy: 0.9689 - val_loss: 0.1051
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9844 - loss: 0.0489 - val_accuracy: 0.9723 - val_loss: 0.0930
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9877 - loss: 0.0382 - val_accuracy: 0.9751 - val_loss: 0.0919
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9901 - loss: 0.0303 - val_accuracy: 0.9737 - val_loss: 0.1059
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9911 - loss: 0.0269 - val_accuracy: 0.9722 - val_loss: 0.1101
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9922 - loss: 0.0235 - val_accuracy: 0.9764 - val_loss: 0.0930
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9948 - loss: 0.0166 - val_accuracy: 0.9736 - val_loss: 0.1184
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9948 - loss: 0.0163 - val_accuracy: 0.9742 - val_loss: 0.1129
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9948 - loss: 0.0170 - val_accuracy: 0.9754 - val_loss: 0.1146
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9955 - loss: 0.0134 - val_accuracy: 0.9752 - val_loss: 0.1175
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9959 - loss: 0.0126 - val_accuracy: 0.9778 - val_loss: 0.1132
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9964 - loss: 0.0108 - val_accuracy: 0.9739 - val_loss: 0.1252
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9957 - loss: 0.0125 - val_accuracy: 0.9768 - val_loss: 0.1182
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9965 - loss: 0.0110 - val_accuracy: 0.9768 - val_loss: 0.1269
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9965 - loss: 0.0109 - val_accuracy: 0.9711 - val_loss: 0.1570
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9962 - loss: 0.0101 - val_accuracy: 0.9748 - val_loss: 0.1451
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9781 - val_loss: 0.1243
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9787 - loss: 0.1181
# Test Loss: 0.11813277751207352
# Test Accuracy: 0.9786999821662903

# %%
from tensorflow.keras.layers import Dense, Flatten, Embedding, Input, Dropout, GlobalAveragePooling1D
from tensorflow.keras.models import Sequential

(x_train,y_train),(x_test,y_test) = tf.keras.datasets.imdb.load_data(num_words=10000)# limit to top 10,000 most frequent words = less traintime and overfitting  

x_train.shape, y_train.shape, x_test.shape, y_test.shape #25000 train and 25000 test samples

print(y_train[0:5]) # reviews of first five (1=positive, 0=negative) 


# the ANN requires all input sequences to be of the same length. 
# We can achieve this by padding shorter sequences with zeros and truncating longer sequences to a fixed length.
from tensorflow.keras.preprocessing.sequence import pad_sequences

x_train = pad_sequences(x_train, maxlen=200)
x_test  = pad_sequences(x_test,  maxlen=200)
x_train.shape, x_test.shape # (25000, 200) (25000, 200)

model = Sequential([
    Input(shape=(200,)),
    Embedding(10000, 128),
    GlobalAveragePooling1D(), # reduce overfitting 
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5), # reduce overfitting
    Dense(1, activation='sigmoid')
])

model.summary()

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(x_train,y_train,epochs=10,validation_split=0.2)

# Plot training and validation loss over epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch') 
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# Plot training and validation accuracy over epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# [1 0 0 1 0]
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)         │ (None, 200, 128)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_10 (Flatten)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,288,321 (4.91 MB)
#  Trainable params: 1,288,321 (4.91 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 36s 28ms/step - accuracy: 0.7657 - loss: 0.4761 - val_accuracy: 0.8480 - val_loss: 0.3441
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.8910 - loss: 0.2746 - val_accuracy: 0.8736 - val_loss: 0.3173
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9151 - loss: 0.2183 - val_accuracy: 0.8656 - val_loss: 0.3273
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9365 - loss: 0.1738 - val_accuracy: 0.8786 - val_loss: 0.3282
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9463 - loss: 0.1563 - val_accuracy: 0.8802 - val_loss: 0.3439
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9560 - loss: 0.1285 - val_accuracy: 0.8718 - val_loss: 0.3628
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9592 - loss: 0.1182 - val_accuracy: 0.8672 - val_loss: 0.4113
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9639 - loss: 0.1041 - val_accuracy: 0.8554 - val_loss: 0.5067
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9676 - loss: 0.0926 - val_accuracy: 0.8682 - val_loss: 0.4704
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.9715 - loss: 0.0829 - val_accuracy: 0.8702 - val_loss: 0.5288
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8485 - loss: 0.5892
# Test Loss: 0.5892159938812256
# Test Accuracy: 0.8484799861907959
