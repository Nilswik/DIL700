# %% [markdown]
# Multi-Task Learning for Classification with Keras
#
#     Load the CIFAR-10 dataset, pre-process data and build a model capable of performing multiple image classifications concurrently with Multiple-Task Learning. The tasks are:
#
#     multi-class classification on the modified CIFAR10 dataset (airplane, automobile, bird, cat, dog, frog, ship and truck labels)
#     binary classification (labels are animal and vehicle)
#
#     Train the model and evaluate the model’s performance
