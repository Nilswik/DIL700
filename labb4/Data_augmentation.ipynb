# %% [markdown]
#     Use tf_flowers dataset which has 5 classes. Re-size and re-scale data. use the Keras preprocessing layers for data augmentation such as keras.layers.RandomFlip Links to an external site.and tf.keras.layers.RandomRotation Links to an external site..
#     Make the preprocessing layers part of your model OR apply the preprocessing layers to your dataset
#     Create custom data augmentation layers. for finer control, write your own data augmentation pipelines or layers using data Links to an external site.and tf.image Links to an external site..
#     Train the models.
