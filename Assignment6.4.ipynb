# %% [markdown]
# The following is for one step ahead forecasting.
#
# Linear model MSE: 0.0039873626083135605
#
# Simple RNN MSE: 0.01093440130352974
#
# DeepRNN MSE: 0.003067892976105213
#
# DeepRNN with layer normalization MSE: 0.0030999190639704466
#
# DeepRNN with batch normalization MSE: 0.004257421009242535
#
# LSTM MSE: 0.0024769341107457876
#
# GRU MSE: 0.0033953548409044743
#
#
#
# linear model MSE: 0.0039873626083135605
# ![image.png](attachment:image.png)
#
# Simple RNN MSE: 0.01093440130352974
# ![image-2.png](attachment:image-2.png)
#
# DeepRNN MSE: 0.003067892976105213
# ![image-4.png](attachment:image-4.png)
#
# DeepRNN with layer normalization MSE: 0.0030999190639704466
# ![image-3.png](attachment:image-3.png)
#
# DeepRNN with batch normalization MSE: 0.004257421009242535
# ![image-5.png](attachment:image-5.png)
#
# LSTM MSE: 0.0024769341107457876
# ![image-6.png](attachment:image-6.png)
#
# GRU MSE: 0.0033953548409044743
# ![image-7.png](attachment:image-7.png)
