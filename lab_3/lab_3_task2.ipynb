# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Load dataset
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Flatten and normalise
X_train = X_train.reshape(-1, 28*28).astype("float32") / 255.0
X_test  = X_test.reshape(-1, 28*28).astype("float32") / 255.0

# %%
# Builds a model with different activation functions
def build_deep_model(activation): # parametrize the activation function

    model = keras.Sequential()
    
    # Input layer
    model.add(layers.Input(shape=(784,)))

    # 100 hidden layers
    for _ in range(100):
        model.add(layers.Dense(256, activation=activation))

    # Output layer
    model.add(layers.Dense(10, activation="softmax"))

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
def build_deep_model_relu_elu(activation="relu"):

    model = keras.Sequential()
    model.add(layers.Input(shape=(784,)))

    for _ in range(100):
        model.add(
            layers.Dense(
                256,
                kernel_initializer="he_normal",
                use_bias=True
            )
        )
        model.add(layers.BatchNormalization())
        model.add(layers.Activation(activation))
        model.add(layers.Dropout(0.2))

    model.add(layers.Dense(10, activation="softmax"))

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
def build_deep_model_selu():

    model = keras.Sequential()
    model.add(layers.Input(shape=(784,)))

    for _ in range(100):
        model.add(
            layers.Dense(
                256,
                activation="selu",
                kernel_initializer="lecun_normal"
            )
        )
        model.add(layers.AlphaDropout(0.1))

    model.add(layers.Dense(10, activation="softmax"))

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
model = build_deep_model_selu()
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout (AlphaDropout)    │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_1 (AlphaDropout)  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │        65,792 │
# ...

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=5,
    batch_size=128,
    verbose=1
)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 162s 225ms/step - accuracy: 0.1003 - loss: 2.4112 - val_accuracy: 0.1000 - val_loss: 5.8663
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 208s 444ms/step - accuracy: 0.1015 - loss: 2.3227 - val_accuracy: 0.1000 - val_loss: 2.4704
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 212s 453ms/step - accuracy: 0.0998 - loss: 2.3251 - val_accuracy: 0.1000 - val_loss: 2.3641
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 244s 521ms/step - accuracy: 0.1007 - loss: 2.3229 - val_accuracy: 0.1000 - val_loss: 2.3438
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 142s 303ms/step - accuracy: 0.0996 - loss: 2.3216 - val_accuracy: 0.1000 - val_loss: 3.0961

# %%
activations = ["relu", "elu", "sigmoid"]

histories = {}

for act in activations:
    print(f"\nTraining with activation: {act}")
    model = build_deep_model_relu_elu(act)
     
    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=5,
        batch_size=128,
        verbose=1
    )
    
    histories[act] = history
# Out:
# Training with activation: relu
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 525s 769ms/step - accuracy: 0.1021 - loss: 2.3981 - val_accuracy: 0.1000 - val_loss: 2.3041
# Epoch 2/5
#  42/469 ━━━━━━━━━━━━━━━━━━━━ 2:35 365ms/step - accuracy: 0.0999 - loss: 2.3328
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       6 print(f"\nTraining with activation: {act}")
#       7 model = build_deep_model_relu_elu(act)
# ----> 9 history = model.fit(
#      10     X_train, y_train,
#      11     validation_data=(X_test, y_test),
#      12     epochs=5,
#      13     batch_size=128,
#      14     verbose=1
#      15 )
#      17 histories[act] = history
#
# File c:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# ...

# %%
def measure_gradients(model, X_batch, y_batch):
    with tf.GradientTape() as tape:
        predictions = model(X_batch)
        loss = tf.keras.losses.sparse_categorical_crossentropy(
            y_batch, predictions
        )

    grads = tape.gradient(loss, model.trainable_weights)

    grad_magnitudes = [
        tf.reduce_mean(tf.abs(g)).numpy()
        for g in grads if g is not None
    ]

    return grad_magnitudes

# %%
activations = ["sigmoid", "relu", "elu"]
results = {}

for act in activations:
    model = build_deep_model(act)
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    model.fit(X_train, y_train, epochs=1, batch_size=128, verbose=0)

    grads = measure_gradients(model, X_train[:128], y_train[:128])
    results[act] = grads

# %%
#Visualize dying ReLUs by plotting the distribution of activations in the first hidden layer for the ReLU model
relu_model = build_deep_model_relu_elu("relu")
relu_model.fit(X_train, y_train, epochs=5, batch_size=128, verbose=1)
layer_outputs = [layer.output for layer in relu_model.layers[:2]]
activation_model = Model(inputs=relu_model.input, outputs=layer_outputs)
activations = activation_model.predict(X_train)

plt.figure(figsize=(12, 5))
for i in range(10):   
    plt.subplot(2, 5, i+1)
    plt.imshow(activations[0][i].reshape(28, 28), cmap="gray")
    plt.axis("off")    
plt.show()

# %%
# Visualize ElU activations
elu_model = build_deep_model_relu_elu("elu")
elu_model.fit(X_train, y_train, epochs=5, batch_size=128, verbose=1)
layer_outputs = [layer.output for layer in elu_model.layers[:2]]
activation_model = Model(inputs=elu_model.input, outputs=layer_outputs)
activations = activation_model.predict(X_train) 

plt.figure(figsize=(12, 5))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(activations[0][i].reshape(28, 28), cmap="gray")
    plt.axis("off")    
plt.show()

# %%
# Visalize selu self normalization by plotting the distribution of activations in the first hidden layer for the SELU model
selu_model = build_deep_model_selu()
selu_model.fit(X_train, y_train, epochs=5, batch_size=128, verbose=1)
layer_outputs = [layer.output for layer in selu_model.layers[:2]]
activation_model = Model(inputs=selu_model.input, outputs=layer_outputs)
activations = activation_model.predict(X_train)
plt.figure(figsize=(12, 5))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(activations[0][i].reshape(28, 28), cmap="gray")
    plt.axis("off")
plt.show()

# %% [markdown]
# Sigmoid: This function triggers severe vanishing gradients because its maximum derivative is only 0.25, meaning the error signal is multiplied by at most 1/4 at every layer until it effectively disappears before reaching the input.
#
# ReLU: While it avoids saturation for positive values, it often leads to "dying neurons" where layers output zero and stop updating entirely, or it causes exploding gradients because the outputs are not capped.
#
# ELU: It attempts to fix the "dying" issue by allowing negative values with a smooth gradient, but in a 100-layer stack without normalization, it still suffers from extreme instability and shift in mean activations.
#
# SELU: This is the only function designed to be self-normalizing to prevent both vanishing and exploding gradients, though it requires a specific initializer (LeCun Normal) to maintain a mean of 0 and variance of 1 across such extreme depth.
