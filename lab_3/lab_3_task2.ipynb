# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Load dataset
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Flatten and normalise
X_train = X_train.reshape(-1, 28*28).astype("float32") / 255.0
X_test  = X_test.reshape(-1, 28*28).astype("float32") / 255.0

# %%
# Builds a model with different activation functions
def build_deep_model(activation): # parametrize the activation function

    model = keras.Sequential()
    
    # Input layer
    model.add(layers.Input(shape=(784,)))

    # 100 hidden layers
    for _ in range(100):
        model.add(layers.Dense(256, activation=activation))

    # Output layer
    model.add(layers.Dense(10, activation="softmax"))

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
def build_deep_model_relu_elu(activation="relu"):

    model = keras.Sequential()
    model.add(layers.Input(shape=(784,)))

    for _ in range(100):
        model.add(
            layers.Dense(
                256,
                kernel_initializer="he_normal",
                use_bias=False
            )
        )
        model.add(layers.BatchNormalization())
        model.add(layers.Activation(activation))
        model.add(layers.Dropout(0.2))

    model.add(layers.Dense(10, activation="softmax"))

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
def build_deep_model_selu():

    model = keras.Sequential()
    model.add(layers.Input(shape=(784,)))

    for _ in range(100):
        model.add(
            layers.Dense(
                256,
                activation="selu",
                kernel_initializer="lecun_normal"
            )
        )
        model.add(layers.AlphaDropout(0.1))

    model.add(layers.Dense(10, activation="softmax"))

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
model = build_deep_model_selu()
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_505 (Dense)               │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout (AlphaDropout)    │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_506 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_1 (AlphaDropout)  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_507 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_2 (AlphaDropout)  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_508 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_3 (AlphaDropout)  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_509 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_4 (AlphaDropout)  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_510 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_5 (AlphaDropout)  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_511 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_6 (AlphaDropout)  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_512 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_7 (AlphaDropout)  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_513 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_8 (AlphaDropout)  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_514 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_9 (AlphaDropout)  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_515 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_10 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_516 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_11 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_517 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_12 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_518 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_13 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_519 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_14 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_520 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_15 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_521 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_16 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_522 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_17 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_523 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_18 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_524 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_19 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_525 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_20 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_526 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_21 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_527 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_22 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_528 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_23 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_529 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_24 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_530 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_25 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_531 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_26 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_532 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_27 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_533 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_28 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_534 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_29 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_535 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_30 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_536 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_31 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_537 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_32 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_538 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_33 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_539 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_34 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_540 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_35 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_541 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_36 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_542 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_37 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_543 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_38 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_544 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_39 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_545 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_40 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_546 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_41 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_547 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_42 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_548 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_43 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_549 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_44 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_550 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_45 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_551 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_46 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_552 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_47 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_553 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_48 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_554 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_49 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_555 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_50 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_556 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_51 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_557 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_52 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_558 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_53 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_559 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_54 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_560 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_55 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_561 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_56 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_562 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_57 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_563 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_58 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_564 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_59 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_565 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_60 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_566 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_61 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_567 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_62 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_568 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_63 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_569 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_64 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_570 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_65 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_571 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_66 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_572 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_67 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_573 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_68 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_574 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_69 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_575 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_70 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_576 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_71 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_577 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_72 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_578 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_73 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_579 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_74 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_580 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_75 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_581 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_76 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_582 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_77 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_583 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_78 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_584 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_79 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_585 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_80 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_586 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_81 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_587 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_82 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_588 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_83 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_589 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_84 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_590 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_85 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_591 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_86 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_592 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_87 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_593 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_88 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_594 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_89 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_595 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_90 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_596 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_91 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_597 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_92 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_598 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_93 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_599 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_94 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_600 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_95 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_601 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_96 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_602 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_97 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_603 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_98 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_604 (Dense)               │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ alpha_dropout_99 (AlphaDropout) │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_605 (Dense)               │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,716,938 (25.62 MB)
#  Trainable params: 6,716,938 (25.62 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=5,
    batch_size=128,
    verbose=1
)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 169s 183ms/step - accuracy: 0.1004 - loss: 2.4042 - val_accuracy: 0.1000 - val_loss: 36.0993
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 88s 188ms/step - accuracy: 0.1015 - loss: 2.3260 - val_accuracy: 0.1000 - val_loss: 2.4282
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7225s 15s/step - accuracy: 0.0983 - loss: 2.3252 - val_accuracy: 0.1000 - val_loss: 2.3230
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 161325s 345s/step - accuracy: 0.0993 - loss: 2.3231 - val_accuracy: 0.1000 - val_loss: 2.3329
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 93s 199ms/step - accuracy: 0.0997 - loss: 2.3217 - val_accuracy: 0.1000 - val_loss: 2.3217

# %%
activations = ["relu", "elu", "selu"]

histories = {}

for act in activations:
    print(f"\nTraining with activation: {act}")
    model = build_deep_model(act)
     
    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=5,
        batch_size=128,
        verbose=1
    )
    
    histories[act] = history
# Out:
# Training with activation: relu
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 142s 172ms/step - accuracy: 0.0993 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 81s 173ms/step - accuracy: 0.0973 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 81s 172ms/step - accuracy: 0.0991 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 77s 164ms/step - accuracy: 0.0999 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 74s 159ms/step - accuracy: 0.0980 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
#
# Training with activation: elu
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 131s 162ms/step - accuracy: 0.1000 - loss: 2.3374 - val_accuracy: 0.1000 - val_loss: 2.3163
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 94s 201ms/step - accuracy: 0.0999 - loss: 2.3126 - val_accuracy: 0.1000 - val_loss: 2.3091
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 339s 724ms/step - accuracy: 0.1015 - loss: 2.3116 - val_accuracy: 0.1000 - val_loss: 2.3147
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 109s 231ms/step - accuracy: 0.0990 - loss: 2.3105 - val_accuracy: 0.1000 - val_loss: 2.3101
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 70s 150ms/step - accuracy: 0.0998 - loss: 2.3115 - val_accuracy: 0.1000 - val_loss: 2.3056
#
# Training with activation: selu
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 177s 251ms/step - accuracy: 0.1001 - loss: 2.4983 - val_accuracy: 0.1000 - val_loss: 2.3572
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 115s 246ms/step - accuracy: 0.1000 - loss: 2.3517 - val_accuracy: 0.1000 - val_loss: 2.3618
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 113s 241ms/step - accuracy: 0.1013 - loss: 2.3418 - val_accuracy: 0.1000 - val_loss: 2.3204
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 120s 257ms/step - accuracy: 0.0986 - loss: 2.3423 - val_accuracy: 0.1000 - val_loss: 2.3602
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 119s 253ms/step - accuracy: 0.0997 - loss: 2.3347 - val_accuracy: 0.1000 - val_loss: 2.3217
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
